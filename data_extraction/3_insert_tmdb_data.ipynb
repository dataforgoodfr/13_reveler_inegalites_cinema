# %%
import json
import requests
import pandas as pd
from http import HTTPStatus

from database.getdata import query_data, get_connection, execute_query

# %% [markdown]
# ### Récupération des données de l'API TMDB

# %%
def get_last_updated_movies_id(api_key: str) -> int:
    """
    Get the ID of the latest movie added to the TMDB database.
    """
    start_date = "2025-02-15"
    end_date = "2025-02-21"
    n_pages = 1
    url = f"https://api.themoviedb.org/3/movie/changes?end_date={end_date}&page={n_pages}&start_date={start_date}"
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {api_key}",
    }

    # Retry the request until it succeeds
    retries = 0
    while retries < 2:
        try:
            response = requests.get(url, headers=headers)
            break
        except Exception:
            retries += 1

    response_in_json = json.loads(response.text)

    return response_in_json

# %%
def get_movies(api_key : str, origin_country : str) -> dict:
    """
    Get ID of movies from a country.
    """
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=fr-FR&page=1&with_origin_country={origin_country}"
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {api_key}"
    }

    response = requests.get(url, headers=headers)
    response_in_json = json.loads(response.text)

    return response_in_json

french_movies = get_movies("FR")
french_movies
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/pqulyfkug9A7TmmRn5zrbRA8TAY.jpg',
#    'genre_ids': [28, 35],
#    'id': 1255788,
#    'original_language': 'fr',
#    'original_title': 'Le Jardinier',
#    'overview': 'Chaque année, le Premier ministre fait éliminer une liste de gêneurs au nom de la raison d’État. Bien malgré lui, le nom de Serge Shuster, conseiller spécial à la présidence, s’y retrouve. Lui et sa famille sont condamnés à une mort certaine. Mais ce que tout le monde ignore, c’est que les Shuster ont un nouveau jardinier, Léo, qui par le passé n’a pas cisaillé que des haies.',
#    'popularity': 180.881,
#    'poster_path': '/qxqwLXgd4vjouSsxKXbGhQyjwoa.jpg',
#    'release_date': '2025-01-30',
#    'title': 'Le Jardinier',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 81},
#   {'adult': False,
#    'backdrop_path': '/zwSDvbnN51JqU1ULzPnEc22DkqV.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 1272149,
#    'original_language': 'en',
#    'original_title': 'Bridget Jones: Mad About the Boy',
#    'overview': 'Bridget Jones a cinquante ans et après le décès de son époux, elle se remet sur le marché des rencontres amoureuses.',
#    'popularity': 131.538,
#    'poster_path': '/17skglkX7rRDayZyFW1YotbUk5H.jpg',
#    'release_date': '2025-02-12',
#    'title': 'Bridget Jones : Folle de lui',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 122},
#   {'adult': False,
#    'backdrop_path': '/b4vPyaCEP53fVDBj0HqFukICiyk.jpg',
#    'genre_ids': [28, 53],
#    'id': 1154215,
#    'original_language': 'fr',
#    'original_title': 'Elyas',
#    'overview': 'Elyas, ancien soldat des Forces Spéciales, solitaire et paranoïaque, devient garde du corps pour Nour, 13 ans et sa mère Amina, venues du Moyen-Orient. Tandis que l’ex-guerrier et la jeune fille s’apprivoisent, un mystérieux commando les prend pour cibles. Elyas ne reculera devant rien pour la sauver.',
#    'popularity': 92.678,
#    'poster_path': '/zuwf11mv6ju9Kf8PtlUjB0OzrBg.jpg',
#    'release_date': '2024-07-03',
#    'title': 'Elyas',
#    'video': False,
#    'vote_average': 6.204,
#    'vote_count': 93},
#   {'adult': False,
#    'backdrop_path': '/cBTwQKMd7Vn6rGTGBtoFLIfj7uM.jpg',
#    'genre_ids': [16, 12, 28, 14],
#    'id': 1147416,
#    'original_language': 'fr',
#    'original_title': 'Miraculous World : Londres, la course contre le temps',
#    'overview': "Afin de sauver l'avenir d'un terrible sort, Marinette devient Chronobug et fait équipe avec Bunnyx pour vaincre un mystérieux adversaire qui voyage dans le temps. Qui est ce nouveau super-méchant, et pourquoi est-il déterminé à dévoiler l'identité secrète de super-héros de Marinette ? Le seul espoir de Marinette est de vaincre son nouvel ennemi pour empêcher la fin de la Coccinelle et des temps !",
#    'popularity': 82.826,
#    'poster_path': '/imGI4R15rMl8B3wPROwkVuJDsc2.jpg',
#    'release_date': '2024-11-14',
#    'title': 'Miraculous World : Londres, la course contre le temps',
#    'video': False,
#    'vote_average': 7.302,
#    'vote_count': 202},
#   {'adult': False,
#    'backdrop_path': '/csQSGH0QU8D3Ov5YLEYuHep8ihA.jpg',
#    'genre_ids': [878, 53, 12, 28],
#    'id': 1196470,
#    'original_language': 'fr',
#    'original_title': 'Оцеляване',
#    'overview': 'Une catastrophe bouleverse la planète : les pôles magnétiques de la Terre se sont inversés. Les océans ont anéanti les continents, laissant derrière eux un vaste désert. Dans ce monde ravagé, une famille doit lutter pour sa survie. Quand les pôles s’inverseront à nouveau, il sera trop tard.',
#    'popularity': 67.258,
#    'poster_path': '/901kRttzfLScns7ss7RyKqG6d2A.jpg',
#    'release_date': '2024-06-19',
#    'title': 'Оцеляване',
#    'video': False,
#    'vote_average': 5.959,
#    'vote_count': 148},
#   {'adult': False,
#    'backdrop_path': '/pz0wQh69Fc88xJgEBGCnr8RHmQj.jpg',
#    'genre_ids': [35],
#    'id': 1361622,
#    'original_language': 'fr',
#    'original_title': 'Lune de miel avec ma mère',
#    'overview': "Largué devant l'autel par sa fiancée partie retrouver son ex, un jeune homme n'a pas vraiment d'autre choix que d'emmener sa propre mère en lune de miel romantique.",
#    'popularity': 63.971,
#    'poster_path': '/bzW0afBIyWZ0bjCje8GPezvETy0.jpg',
#    'release_date': '2025-02-11',
#    'title': 'Lune de miel avec ma mère',
#    'video': False,
#    'vote_average': 5.3,
#    'vote_count': 51},
#   {'adult': False,
#    'backdrop_path': '/llIXQAndg5kB6SWlp6ouUdO7Zxd.jpg',
#    'genre_ids': [28, 12, 18],
#    'id': 1084736,
#    'original_language': 'fr',
#    'original_title': 'Le Comte de Monte-Cristo',
#    'overview': 'Victime d’un complot, le jeune Edmond Dantès est arrêté le jour de son mariage pour un crime qu’il n’a pas commis. Après quatorze ans de détention au château d’If, il parvient à s’évader. Devenu immensément riche, il revient sous l’identité du comte de Monte-Cristo pour se venger des trois hommes qui l’ont trahi.',
#    'popularity': 58.169,
#    'poster_path': '/g7kiprYdXxaYCZABWQwTWAgRYjl.jpg',
#    'release_date': '2024-06-28',
#    'title': 'Le Comte de Monte-Cristo',
#    'video': False,
#    'vote_average': 8.043,
#    'vote_count': 1430},
#   {'adult': False,
#    'backdrop_path': '/sQbFupSWM9wUdPj96NZNUOFSP5.jpg',
#    'genre_ids': [28, 12, 53],
#    'id': 1000075,
#    'original_language': 'fr',
#    'original_title': "Largo Winch : Le Prix de l'argent",
#    'overview': 'Depuis l’enlèvement brutal de son fils Noom, Largo Winch fait l’objet d’une impitoyable machination cherchant à l’anéantir et à détruire le groupe W. Pour faire éclater la vérité et retrouver son fils, Largo se lance dans une traque sans relâche. Des forêts canadiennes, en passant par Bangkok jusque dans les profondeurs des mines birmanes il ne sait pas encore qu’il devra faire face aux démons du passé.',
#    'popularity': 58.163,
#    'poster_path': '/hextHjNWD79MAJWux4ScvvzUdrR.jpg',
#    'release_date': '2024-07-31',
#    'title': "Largo Winch : Le Prix de l'argent",
#    'video': False,
#    'vote_average': 6.161,
#    'vote_count': 180},
#   {'adult': False,
#    'backdrop_path': '/zqZzYVE4DWv92xrYSCEELPcLnUP.jpg',
#    'genre_ids': [18, 53, 80],
#    'id': 1278263,
#    'original_language': 'fr',
#    'original_title': 'Les Graines du figuier sauvage',
#    'overview': 'Iman vient d’être promu juge d’instruction au tribunal révolutionnaire de Téhéran quand un immense mouvement de protestations populaires commence à secouer le pays. Dépassé par l’ampleur des évènements, il se confronte à l’absurdité d’un système et à ses injustices mais décide de s’y conformer. À la maison, ses deux filles, Rezvan et Sana, étudiantes, soutiennent le mouvement avec virulence, tandis que sa femme, Najmeh, tente de ménager les deux camps. La paranoïa envahit Iman lorsque son arme de service disparait mystérieusement…',
#    'popularity': 54.948,
#    'poster_path': '/6YThe5RVeVVGm2gOkzykfXSElaO.jpg',
#    'release_date': '2024-09-18',
#    'title': 'Les Graines du figuier sauvage',
#    'video': False,
#    'vote_average': 7.672,
#    'vote_count': 192},
#   {'adult': False,
#    'backdrop_path': '/Eeuq1qmv8UEsd4sX6BSrGNYR19.jpg',
#    'genre_ids': [53, 28],
#    'id': 1001274,
#    'original_language': 'fr',
#    'original_title': 'La Nuit se traîne',
#    'overview': "Ce soir-là, Mady, étudiant le jour et serrurier la nuit, voit sa vie basculer quand il ouvre la mauvaise porte et devient accidentellement complice d'une affaire de grand banditisme. Au cœur d’une ville en pleine ébullition, Mady n'a qu'une nuit pour se tirer d'affaires et retrouver la trace de Claire, celle qui a trahi sa confiance. Le compte à rebours est lancé…",
#    'popularity': 53.29,
#    'poster_path': '/jzZJXEa8KX5hsjCCpRaWc69e9gz.jpg',
#    'release_date': '2024-08-28',
#    'title': 'La Nuit se traîne',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 67},
#   {'adult': False,
#    'backdrop_path': '/eItpQ7dJfSp8aFrX1MdjaUv0HrE.jpg',
#    'genre_ids': [28, 12, 53],
#    'id': 1167271,
#    'original_language': 'en',
#    'original_title': 'Weekend in Taipei',
#    'overview': 'John Lawlor est un redoutable agent de la DEA pour qui le travail passe avant tout. De l’autre côté du globe, Joey Kwang vit sa vie pied au plancher. Au volant, il n’y a pas meilleur pilote qu’elle. Ils se sont rencontrés à Taipei. Leur histoire a été folle, brulante, passionnée. Mais de courte durée… Quinze ans plus tard, le destin les réunit de nouveau à Taipei. Les émotions enfouies refont surface. Dans un monde où le danger rôde à chaque coin de rue, seule la passion qui les avait unis autrefois pourra les sauver…',
#    'popularity': 44.565,
#    'poster_path': '/i4ZfMC9aVGFZhWWpyyyEHFPeQqV.jpg',
#    'release_date': '2024-09-19',
#    'title': 'Week-end à Taipei',
#    'video': False,
#    'vote_average': 6.219,
#    'vote_count': 153},
#   {'adult': False,
#    'backdrop_path': '/u2eA9pqi1q3DvevT7RuDuJHxxBT.jpg',
#    'genre_ids': [18, 53],
#    'id': 974950,
#    'original_language': 'fr',
#    'original_title': 'Emilia Pérez',
#    'overview': "Rita, une avocate sous-estimée travaillant pour un grand cabinet d'avocats plus intéressé à faire sortir les criminels de prison qu'à les traduire en justice, est engagée par le chef d'une organisation criminelle.",
#    'popularity': 44.495,
#    'poster_path': '/r5sYdlJFys6YETQb63lvRR4fKEL.jpg',
#    'release_date': '2024-08-21',
#    'title': 'Emilia Pérez',
#    'video': False,
#    'vote_average': 6.934,
#    'vote_count': 1291},
#   {'adult': False,
#    'backdrop_path': '/liuBLPXvisMRo5w2JEKHXceWq5u.jpg',
#    'genre_ids': [28, 80, 18],
#    'id': 1171640,
#    'original_language': 'fr',
#    'original_title': 'GTMAX',
#    'overview': 'Soélie, une jeune prodige de motocross, voit ses rêves de réussite brisés suite à un accident. Elle se consacre désormais à entraîner son frère, Michael. Quand celui-ci est recruté par des pilotes en scooter Tmax pour un braquage de haut vol à Paris, Soélie doit surmonter ses peurs pour le sauver.',
#    'popularity': 38.789,
#    'poster_path': '/bx92hl70NUhojjO3eV6LqKllj4L.jpg',
#    'release_date': '2024-11-19',
#    'title': 'GTMAX',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 121},
#   {'adult': False,
#    'backdrop_path': '/xqIstzB0ELbYyfzKcYaSwLb4Whs.jpg',
#    'genre_ids': [10749, 18],
#    'id': 976576,
#    'original_language': 'en',
#    'original_title': 'Emmanuelle',
#    'overview': 'Emmanuelle est en quête d’un plaisir perdu. Elle s’envole seule à Hong Kong, pour un voyage professionnel. Dans cette ville-monde sensuelle, elle multiplie les expériences et fait la rencontre de Kei, un homme qui ne cesse de lui échapper.',
#    'popularity': 38.212,
#    'poster_path': '/31byjbcGFDpuYdKiM6bRpArvjXw.jpg',
#    'release_date': '2024-09-25',
#    'title': 'Emmanuelle',
#    'video': False,
#    'vote_average': 5.0,
#    'vote_count': 48},
#   {'adult': False,
#    'backdrop_path': '/ozVwXlfxqNsariipatGwa5px3Pm.jpg',
#    'genre_ids': [28, 878],
#    'id': 240832,
#    'original_language': 'en',
#    'original_title': 'Lucy',
#    'overview': 'Lucy, une jeune étudiante ordinaire, se fait kidnapper. À son réveil, elle découvre que les membres d’une organisation criminelle lui ont inséré un paquet de drogue dans l’estomac dans le but de lui faire passer la frontière. Mais lorsqu’à la suite d’un coup porté à son ventre le produit se déverse dans son corps et s’implante dans son système, la jeune femme en subit les étonnants effets. Cette substance synthétique lui permet de décupler ses capacités intellectuelles et physiques. Devenue un génie autant qu’une véritable machine de guerre, Lucy dispose désormais de pouvoirs illimités et surhumains…',
#    'popularity': 35.057,
#    'poster_path': '/hLKoSzjOPC8tQaA2AmFvDjBbKTw.jpg',
#    'release_date': '2014-07-25',
#    'title': 'Lucy',
#    'video': False,
#    'vote_average': 6.456,
#    'vote_count': 16160},
#   {'adult': False,
#    'backdrop_path': '/qoxriJ6n1qxvG1bBMPnsZBHKGco.jpg',
#    'genre_ids': [10749, 18, 14],
#    'id': 11845,
#    'original_language': 'en',
#    'original_title': 'Intimacy',
#    'overview': "Claire vient chez Jay, l'après-midi. Ils font l'amour. Ils ne se parlent pas, mais il doit se passer quelque chose entre eux parce qu'ils se lèvent ensemble et se couchent à côté de la table, sans un mot. La semaine suivante, à la même heure, elle est à la porte. Ils se déshabillent immédiatement. Si le sexe est un moyen de rencontrer et de connaître les gens, que sait-il d'elle ?",
#    'popularity': 34.499,
#    'poster_path': '/aEWt17Xk5zsEtGLve103XtUw4kh.jpg',
#    'release_date': '2001-01-20',
#    'title': 'Intimité',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 516},
#   {'adult': False,
#    'backdrop_path': '/1fYIvYIwAWID27ZsmpOzAcEDOCv.jpg',
#    'genre_ids': [53, 27, 80, 9648],
#    'id': 1084863,
#    'original_language': 'fr',
#    'original_title': "Le Mangeur d'âmes",
#    'overview': "La commandante Élisabeth Guardiano est chargée d'aller enquêter sur un double meurtre d'une rare brutalité dans une petite commune des Vosges. Sur place, elle rencontre le capitaine de gendarmerie Franck de Rolan qui fait face à une série de disparitions d’enfants. Impuissants face à un village hostile, ils vont être contraints d’unir leurs forces pour découvrir la vérité, une vérité terrifiante empreinte de légendes occultes...",
#    'popularity': 32.771,
#    'poster_path': '/m0HSecww9Tm79pbiXAE9zqLqq9T.jpg',
#    'release_date': '2024-04-24',
#    'title': "Le Mangeur d'âmes",
#    'video': False,
#    'vote_average': 6.143,
#    'vote_count': 136},
#   {'adult': False,
#    'backdrop_path': '/w6MAE6cs8F62iAspnIqwVksAENM.jpg',
#    'genre_ids': [16, 12, 14],
#    'id': 1208491,
#    'original_language': 'fr',
#    'original_title': 'Zak & Wowo, la légende de Lendarys',
#    'overview': "Dans un monde aux paysages verdoyants, l'apparition de terrifiantes créature contraint tous les habitants à se réfugier dans une ville fortifiée. Seuls les intrépides jumeaux Zak et Kyle sont restés à l'extérieur. Mais Kyle disparaît subitement, sans laisser de trace. Son frère Zak part à sa recherche et rencontre sur son chemin Wowo, pachyderme poilu, et Indiana, mystérieuse hors la loi. Ensemble, ils se lancent dans une aventure extraordinaire pour sauver le monde merveilleux qui les entoure.",
#    'popularity': 31.22,
#    'poster_path': '/tgOq45Aijeup6mqEmOWGzYabaVQ.jpg',
#    'release_date': '2024-04-25',
#    'title': 'Zak & Wowo, la légende de Lendarys',
#    'video': False,
#    'vote_average': 5.1,
#    'vote_count': 10},
#   {'adult': False,
#    'backdrop_path': '/hU1Q9YVzdYhokr8a9gLywnSUMlN.jpg',
#    'genre_ids': [16, 12, 28, 14, 10751],
#    'id': 1147400,
#    'original_language': 'fr',
#    'original_title': 'Miraculous World : Paris, Les Aventures de Toxinelle et Griffe Noire',
#    'overview': 'Des porteurs de Miraculous venus d’un autre monde surgissent dans la ville de Paris. Ils viennent d’un univers parallèle où tout est inversé : Toxinelle et Griffe Noire, les alter égos maléfiques de Ladybug et Chat Noir sont les méchants et le porteur du Papillon, Hesperia, est un super-héros. Ensemble Ladybug et Chat Noir – les vrais – vont devoir aider Hespéria à contrer les attaques de leurs doubles maléfiques et les empêcher de s’emparer du Miraculous du Papillon. Mais nos héros pourront-ils aider Hesperia à faire de Toxinelle et Griffe Noire de meilleures personnes ?',
#    'popularity': 30.293,
#    'poster_path': '/4wHrXw9zB4wsibWaAPDkvjNGPnQ.jpg',
#    'release_date': '2023-10-21',
#    'title': 'Miraculous World : Paris, Les Aventures de Toxinelle et Griffe Noire',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 579},
#   {'adult': False,
#    'backdrop_path': '/lBcXozUeABairkTavz3X3ZAtOL0.jpg',
#    'genre_ids': [10749, 80, 18],
#    'id': 959604,
#    'original_language': 'fr',
#    'original_title': "L'Amour ouf",
#    'overview': "Les années 80, dans le nord de la France. Jackie et Clotaire grandissent entre les bancs du lycée et les docks du port. Elle étudie, il traîne. Et puis leurs destins se croisent et c'est l'amour fou. La vie s'efforcera de les séparer mais rien n'y fait, ces deux-là sont comme les deux ventricules du même cœur...",
#    'popularity': 28.916,
#    'poster_path': '/6akNNv4KyrguZUiG4uemfV6toVq.jpg',
#    'release_date': '2024-10-16',
#    'title': "L'Amour ouf",
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 588}],
#  'total_pages': 3074,
#  'total_results': 61461}

# %% [markdown]
# ### Traitement des données récupérées

# %%
# Create a DataFrame from the JSON response
df_movies = pd.DataFrame(french_movies['results'])
print(df_movies.shape[0])

# Map column names to database schema
columns_fr = {
    "title": "nom_originel",
    "original_language": "langue_principale",
    "release_date": "date_sortie_france",
    "vote_average": "tmbd_note_moyenne",
    "vote_count": "tmdb_total_votes",
    "popularity": "tmdb_score",
    "overview": "description",
    "id": "tmdb_id",
}
df_movies.rename(columns=columns_fr, inplace=True)

# Drop columns that are not needed
columns_to_drop = [
    "adult",
    "backdrop_path",
    "poster_path",
    "video",
    "original_title",
    "genre_ids",
    # below is temporary drop until database schema if correctly updated
    "tmbd_note_moyenne", 
    "tmdb_total_votes",
    "tmdb_score",
    "description",
    "tmdb_id",
]
df_movies.drop(columns=columns_to_drop, inplace=True)
df_movies.head()
# Out:
# 20
#   langue_principale date_sortie_france  \
# 0                fr         2025-01-30
# 1                en         2025-02-12
# 2                fr         2024-07-03
# 3                fr         2024-11-14
# 4                fr         2024-06-19
#
#                                         nom_originel
# 0                                       Le Jardinier
# 1                       Bridget Jones : Folle de lui
# 2                                              Elyas
# 3  Miraculous World : Londres, la course contre l...
# 4                                          Оцеляване

# %% [markdown]
# ### Comparaison avec les données déjà en base

# %%
# Get the movies from the database
df_db_movies = query_data("SELECT id, nom_originel FROM inegalites_cinema.film")
print("Number of rows in table inegalites_cinema.film: " + str(df_db_movies.shape[0]))

# Merge the two DataFrames to find the movies that are not already in the database
df_merged = pd.merge(df_movies, df_db_movies, how="left", left_on="nom_originel", right_on="nom_originel")

# Get the ID of the latest movie added to the TMDB database
start_id = int(df_db_movies.loc[:,'id'].max()) + 1
# Get the movies that didn't match
df_new_rows = df_merged[df_merged['id'].isnull()]
# Attribute an ID to the new rows
df_new_rows['id'] = range(start_id, start_id+len(df_new_rows))
df_new_rows.head()
# Out:
# Number of rows in film table from database: 247
# langue_principale     20
# date_sortie_france    20
# nom_originel          20
# id                     0
# dtype: int64
#    langue_principale date_sortie_france  \
# 0                 fr         2025-01-30
# 1                 en         2025-02-12
# 2                 fr         2024-07-03
# 3                 fr         2024-11-14
# 4                 fr         2024-06-19
# 5                 fr         2025-02-11
# 6                 fr         2024-06-28
# 7                 fr         2024-07-31
# 8                 fr         2024-09-18
# 9                 fr         2024-08-28
# 10                en         2024-09-19
# 11                fr         2024-08-21
# 12                fr         2024-11-19
# 13                en         2024-09-25
# 14                en         2014-07-25
# 15                en         2001-01-20
# 16                fr         2024-04-24
# 17                fr         2024-04-25
# 18                fr         2023-10-21
# 19                fr         2024-10-16
#
#                                          nom_originel   id
# 0                                        Le Jardinier  248
# 1                        Bridget Jones : Folle de lui  249
# 2                                               Elyas  250
# 3   Miraculous World : Londres, la course contre l...  251
# 4                                           Оцеляване  252
# 5                           Lune de miel avec ma mère  253
# 6                            Le Comte de Monte-Cristo  254
# 7                   Largo Winch : Le Prix de l'argent  255
# 8                      Les Graines du figuier sauvage  256
# 9                                   La Nuit se traîne  257
# 10                                  Week-end à Taipei  258
# 11                                       Emilia Pérez  259
# 12                                              GTMAX  260
# 13                                         Emmanuelle  261
# 14                                               Lucy  262
# 15                                           Intimité  263
# 16                                  Le Mangeur d'âmes  264
# 17                 Zak & Wowo, la légende de Lendarys  265
# 18  Miraculous World : Paris, Les Aventures de Tox...  266
# 19                                        L'Amour ouf  267

# %% [markdown]
# ### Insertion des données en base

# %%
df_new_rows.to_sql(
    'film',
    get_connection(),
    schema='inegalites_cinema',
    if_exists='append',
    index=False
)
# Out:
# 20
